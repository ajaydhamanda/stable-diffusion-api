# %% [markdown]
# <a href="https://colab.research.google.com/github/ajaydhamanda/stable-diffusion-api/blob/main/DaaS.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install diffuzers

# %%
# !diffuzers api --help

# %%
#env variables
# %env X2IMG_MODEL=stabilityai/stable-diffusion-2-1
# Out:
# env: X2IMG_MODEL=stabilityai/stable-diffusion-2-1

# %%
# %env DEVICE=cuda
# Out:
# env: DEVICE=cuda

# %%
# !diffuzers api --port 10000 & npx localtunnel --port 10000
# Out:
# npx: installed 22 in 1.921s
# your url is: https://thirty-turtles-count-35-203-169-28.loca.lt
# 2023-04-13 15:05:03.983390: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-04-13 15:05:04.928365: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# INFO:     Started server process [9650]
# 2023-04-13 15:05:08.068 INFO    uvicorn.error: Started server process [9650]
# INFO:     Waiting for application startup.
# 2023-04-13 15:05:08.069 INFO    uvicorn.error: Waiting for application startup.
# > INFO    @@@@@ Starting Diffuzes API @@@@@
# > INFO    Text2Image Model: stabilityai/stable-diffusion-2-1
# > INFO    Text2Image Pipeline: Vanilla
# > INFO    Inpainting Model: None
# > INFO    Device: cuda
# ...
